# %% [markdown]
# # Certification Process for Upcoming Expirations

# %% [markdown]
# ## Libraries Import

# %%
import pandas as pd
import numpy as np
from email.message import EmailMessage
import win32com.client as win32
import os
import numpy as np

# %% [markdown]
# ## Get Config

# %% [markdown]
# ### Getting Sheets of the config file

# %%
config_file_path = "../data/Config.xlsx"
df_config = pd.read_excel(config_file_path, sheet_name="Config")
df_data = pd.read_excel(config_file_path, sheet_name="Data")
df_Mail = pd.read_excel(config_file_path, sheet_name="Mail")

# %% [markdown]
# ### Variables

# %%
#Folder path where files are stored
shared_folder = df_config.iloc[0,1]

shared_folder
# Out:
# 'C:\\Users\\25004549\\Documents\\02. UiPath Projects\\00. M1\\02. Certification_upcoming_expirations\\notebook\\data'

# %%
df_data
# Out:
#                Filename   Sheet
# 0  Copy of 10.-SMD.xlsm  OP 1 C
# 1  Copy of 10.-SMD.xlsm  OP 2 C
# 2  Copy of 10.-SMD.xlsm  OP 3 C
# 3  Copy of 10.-SMD.xlsm  OP 5 C
# 4          10.-SMT.xlsm  OP 1 C
# 5          10.-SMT.xlsm  OP 2 C
# 6          10.-SMT.xlsm  OP 3 C
# 7          10.-SMT.xlsm  OP 5 C

# %%
df_Mail
# Out:
#                               To                        CC  \
# 0     gilberto.gaytan@wnc.com.tw  ggaytan_itcj@hotmail.com
# 1  ggaytan.analytics@outlook.com                       NaN
#
#                        CCO
# 0  bto_pachu15@hotmail.com
# 1                      NaN

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Get Data

# %%
df_certifications = pd.read_excel('../data/Copy of 10.-SMD.xlsm',sheet_name='OP 1 C')
# Out:
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df_certifications.sample(5)
# Out:
#      Número                Nombre completo                 Nombre puesto  \
# 752  301756       Castro Soriano, Iridiana                    Operador 1
# 258  207900        Armenta Gonzalez, Roman  Especialista En Ctrl De Prod
# 694  300339     Juarez Perez, Martha Anahi                    Operador 1
# 11   201990  Soto Contreras, Jose Guerrero     Lider Control Inventarios
# 119  202315      Garcia Fernandez, Leticia                    Operador 2
#
#     Unnamed: 3                      Unnamed: 4  \
# 752        NaN                             NaN
# 258        NaN                             NaN
# 694        NaN                             NaN
# 11      202043  Morales Gonzalez, Ma. De Jesus
# 119     289652        Valenzuela Flores, Edgar
#
#                            Unnamed: 5           Unnamed: 6 Unnamed: 7  \
# 752                               NaN                  NaN        NaN
# 258                               NaN                  NaN        730
# 694                               NaN                  NaN        NaN
# 11   Corte de Tablilla (Depanelizado)  2024-12-18 00:00:00        730
# 119            Programacion y PXI SMD  2025-12-02 00:00:00        730
#
#               Unnamed: 8 Unnamed: 9 Unnamed: 10  Unnamed: 11 Unnamed: 12  \
# 752                  NaN        NaN         NaN          NaN         NaN
# 258  1901-12-30 00:00:00     -45404           5          NaN         NaN
# 694                  NaN        NaN         NaN          NaN         NaN
# 11   2026-12-18 00:00:00        240           5          NaN         NaN
# 119  2027-12-02 00:00:00        589           5          NaN         NaN
#
#     Unnamed: 13  Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 752         NaN          NaN         NaN         NaN         NaN
# 258         NaN          NaN         NaN         NaN         NaN
# 694         NaN          NaN         NaN         NaN         NaN
# 11          NaN          NaN         NaN         NaN         NaN
# 119         NaN          NaN         NaN         NaN         NaN

# %% [markdown]
# ## Data Transformation

# %%
def extract_data(shared_folder,filename, sheet):
    df = pd.read_excel((shared_folder + "\\"+filename), sheet_name=sheet)
    #removiendo columnas y filas no necesarias
    df = df.iloc[10:,3:]

    #Conservando columnas por usar
    df = df.iloc[:, :8]

    #promoviendo primera fila como titulos de columnas
    df.columns = df.iloc[0]
    df = df[1:]

    #removiendo nulos
    df = df.dropna()

    #Obteniendo dias de diferencia entre fecha de expiracion y fecha actual
    df['Dias por expirar'] = (pd.to_datetime(df['FECHA DE RECERTIFICACION']) - pd.to_datetime('today')).dt.days

    #filtrar por dias por expirar menores a 100
    df = df[df['Dias por expirar'] < 100]

    #Removiendo columnas no necesarias
    df = df.drop(columns=['DIAS A VENCER','ALERTA', 'PARAMETRO DE CERTIFICACION'])

    #Dejando columnas fecha solo con formato fecha
    df['FECHA DE RECERTIFICACION'] = pd.to_datetime(df['FECHA DE RECERTIFICACION']).dt.date
    df['FECHA DE CERTIFICACION MM/DD/AAAA'] = pd.to_datetime(df['FECHA DE CERTIFICACION MM/DD/AAAA']).dt.date
    return df

# %%
report = []
#Leyyendo los datos de las certificaciones
for row in df_data.itertuples():
    filename = row.Filename 
    sheet = row.Sheet
    
    try:
        df = extract_data(shared_folder, filename, sheet)
        report.append(df)
    except Exception as e:
        print(f"Error al procesar el archivo {filename} y hoja {sheet}: {e}")

df_report = pd.concat(report, ignore_index=True)
# Out:
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Error al procesar el archivo Copy of 10.-SMD.xlsm y hoja OP 5 C: Worksheet named 'OP 5 C' not found
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\25004549\Documents\02. UiPath Projects\00. M1\02. Certification_upcoming_expirations\notebook\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df_report
# Out:
# 10     PID                             NOMBRE  \
# 0   280178         Castañon Quintanar, Alicia
# 1   280178         Castañon Quintanar, Alicia
# 2   203358            Vazquez Ordaz, Virginia
# 3   202311            Carrera Rivera, Eugenia
# 4   202311            Carrera Rivera, Eugenia
# ..     ...                                ...
# 80  202259  Velazquez Delgado, Adriana Ivette
# 81  202303    Hernandez Centeno, Santa Alicia
# 82  207799          Carrillo Ortiz, Elizabeth
# 83  288284           Soto Rico, Ivan De Jesus
# 84  289658             Marquez Sierra, Yaslin
#
# 10                     CERTIFICACION FECHA DE CERTIFICACION MM/DD/AAAA  \
# 0   Corte de Tablilla (Depanelizado)                        2024-08-06
# 1             Programacion y PXI SMD                        2024-08-06
# 2             Programacion y PXI SMD                        2024-02-01
# 3   Corte de Tablilla (Depanelizado)                        2024-02-01
# 4             Programacion y PXI SMD                        2024-02-01
# ..                               ...                               ...
# 80   Manejo y uso de maquinas de SMT                        2024-03-22
# 81   Manejo y uso de maquinas de SMT                        2024-01-31
# 82               Operador  Universal                        2024-03-22
# 83   Manejo y uso de maquinas de SMT                        2024-03-22
# 84   Manejo y uso de maquinas de SMT                        2023-10-03
#
# 10 FECHA DE RECERTIFICACION  Dias por expirar
# 0                2026-08-06                93
# 1                2026-08-06                93
# 2                2026-01-31               -94
# 3                2026-01-31               -94
# 4                2026-01-31               -94
# ..                      ...               ...
# 80               2026-03-22               -44
# 81               2026-01-30               -95
# 82               2024-02-02              -823
# 83               2026-03-22               -44
# 84               2025-10-02              -215
#
# [85 rows x 6 columns]

# %%
df_report.sample(15)
# Out:
# 10     PID                             NOMBRE  \
# 7   278988   Reynoso Rubio, Teresita De Jesus
# 67  208914   Quezada Alvarado, Laura Patricia
# 15  202043     Morales Gonzalez, Ma. De Jesus
# 12  208510            Santos Alonso, Patricia
# 44  207799          Carrillo Ortiz, Elizabeth
# 51  202315          Garcia Fernandez, Leticia
# 10  287333     Nevarez Olivas, Vanessa Lizeth
# 41  202236      Hernandez Santos, Alejandrina
# 47  208354            Padilla Silva, Angelica
# 52  202252    Candelario Martinez, Flor Maria
# 22  208914   Quezada Alvarado, Laura Patricia
# 36  202316           Suarez Palomares, Brenda
# 11  280178         Castañon Quintanar, Alicia
# 33  202231             Mateos Martin, Edmundo
# 8   294787  Garcia Ordoñez, Maria Del Refugio
#
# 10                     CERTIFICACION FECHA DE CERTIFICACION MM/DD/AAAA  \
# 7             Programacion y PXI SMD                        2024-03-08
# 67                        Prueba ICT                        2024-05-24
# 15                         Soldadura                        2024-02-22
# 12                         Soldadura                        2024-02-21
# 44            Programacion y PXI SMT                        2024-08-06
# 51                         Soldadura                        2024-02-21
# 10  Corte de Tablilla (Depanelizado)                        2024-05-27
# 41  Corte de Tablilla (Depanelizado)                        2024-04-04
# 47            Programacion y PXI SMT                        2024-02-01
# 52                         Soldadura                        2024-02-22
# 22                        Prueba AOI                        2024-02-26
# 36                        Prueba ICT                        2024-05-24
# 11                         Soldadura                        2024-08-12
# 33                        Prueba AOI                        2024-05-24
# 8             Programacion y PXI SMD                        2024-04-04
#
# 10 FECHA DE RECERTIFICACION  Dias por expirar
# 7                2026-03-08               -58
# 67               2026-05-24                19
# 15               2026-02-21               -73
# 12               2026-02-20               -74
# 44               2026-08-06                93
# 51               2026-02-20               -74
# 10               2026-05-27                22
# 41               2026-04-04               -31
# 47               2026-01-31               -94
# 52               2026-02-21               -73
# 22               2026-02-25               -69
# 36               2026-05-24                19
# 11               2026-08-12                99
# 33               2026-05-24                19
# 8                2026-04-04               -31

# %% [markdown]
# ## Data Modeling

# %%
df_report.to_excel('../reports/Certifications to expiring.xlsx', index=False)
ruta_archivo = os.path.abspath("../reports/Certifications to expiring.xlsx")

# %% [markdown]
# ### Config Mail List to send the report

# %%
list_to = ";".join(df_Mail["To"].dropna().astype(str))
list_cc = ";".join(df_Mail["CC"].dropna().astype(str))
list_cco = ";".join(df_Mail["CCO"].dropna().astype(str))

# %%
list_cc
# Out:
# 'ggaytan_itcj@hotmail.com'

# %%
sender = "p_m1dmis_rpa01@wnc.com.tw"
receiver = list_to
pwd = 'Wnewebmx2026.'


outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.SentOnBehalfOfName = sender
mail.To = receiver
mail.cc = list_cc
#mail.bcc = list_cco
mail.Subject = "Certificaciones por expirar"
mail.Body = "Buen dia, se comparte el reporte de certificaciones por expirar en menos de 100 dias \nFavor de incluir en programa semanal \nSaludos!"
mail.attachments.Add(ruta_archivo)
mail.Send()


#msg  = EmailMessage()
#msg['From'] = sender
#msg['To'] = list_to   
#msg['Subject'] = "Certificaciones por expirar en menos de 100 dias"
#msg.set_content("Hola, adjunto el reporte de certificaciones por expirar en menos de 100 dias")

# %%
outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.SentOnBehalfOfName = sender
mail.To = receiver
mail.cc = list_cc
#mail.bcc = list_cco
mail.Subject = "Certificaciones por expirar"
mail.Body = "Buen dia, se comparte el reporte de certificaciones por expirar en menos de 100 dias \nFavor de incluir en programa semanal \nSaludos!"
mail.attachments.Add(ruta_archivo)
mail.Send()
